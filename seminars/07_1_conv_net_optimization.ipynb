# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>"Глубокое обучение". Продвинутый поток</b></h3>

# %% [markdown]
# Работаем с датасетом CIFAR10, здесь мы уже экспериментируем с батчнормом и аугментацией данных

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

from tqdm import tqdm_notebook

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %matplotlib inline

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## 0. Data preparation

# %%
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])  # преобразовываем изображение png в тензор и нормализуем по каждому каналу

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform_train
)

trainloader = torch.utils.data.DataLoader(   # даталоадер, разбиение по батчам
    trainset,
    batch_size=128,
    shuffle=True,
    num_workers=2
)

testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform_test
)
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=100,
    shuffle=False,
    num_workers=2
)
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 30.7MB/s]

# %% [markdown]
# ## 1. Custom Convolutional model

# %% [markdown]
# Попробуем написать свою собственную маленькую конволюционную модель

# %% [markdown]
# Данная функция переводит изображение в плоский вектор, ей мы будем пользоваться после сверточных слоев

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.shape[0], -1)

# %% [markdown]
# Набор сверток представляет собой feature extractor. Раньше этот набор писался вручную (параметры свертки, то есть наши ядра) и некоторые начальные параметры были осознанные, указывали на границы, закорючки. Но сейчас в этом нет необходимости, так как сейчас ядра это обучаемый параметр

# %%
model = nn.Sequential()

# dense "head"
model.add_module('conv1', nn.Conv2d(3, 64, 3))
model.add_module('conv1_relu', nn.ReLU())
model.add_module('conv2', nn.Conv2d(64, 10, 3))
model.add_module('conv2_relu', nn.ReLU())

model.add_module('flat', Flatten())
model.add_module('dense', nn.Linear(10*28*28, 10))

# %%
import torchsummary

# %%
torchsummary.summary(model.cuda(), (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 30, 30]           1,792
#               ReLU-2           [-1, 64, 30, 30]               0
#             Conv2d-3           [-1, 10, 28, 28]           5,770
#               ReLU-4           [-1, 10, 28, 28]               0
#            Flatten-5                 [-1, 7840]               0
#             Linear-6                   [-1, 10]          78,410
# ================================================================
# Total params: 85,972
# Trainable params: 85,972
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.06
# Params size (MB): 0.33
# Estimated Total Size (MB): 1.40
# ----------------------------------------------------------------

# %% [markdown]
# Здесь мы видим forward pass, так мы можем узнать как много оперативной памяти или GPU нам нужно для обработки батчей, и соответственно можем это регулировать под возможности компьютера

# %% [markdown]
# ## 2. Write train and test function

# %%
def train(model, optim, criterion, dataloader, epoch, device):
    total = 0
    correct = 0
    train_loss = 0

    model.train()
    for data, label in dataloader:
        data, label = data.to(device), label.to(device)
        optim.zero_grad()
        output = model(data)
        loss = criterion(output, label)
        loss.backward()
        optim.step()

        train_loss += loss.item()
        pred = output.argmax(1)
        total += output.shape[0]
        correct += pred.eq(label).sum().item()
    return train_loss / total, 100. * correct / total

# %%
def test(model, criterion, dataloader, epoch, device, best_acc, model_name='model'):
    total = 0
    correct = 0
    test_loss = 0

    model.eval()
    with torch.no_grad():
        for data, label in dataloader:
            data, label = data.to(device), label.to(device)
            output = model(data)

            loss = criterion(output, label)

            test_loss += loss
            pred = output.argmax(1)
            correct += torch.eq(pred, label).sum().item()
            total += data.shape[0]

    acc = 100.*correct/total
    if acc > best_acc:
        # print('Saving..')
        state = {
            'net': model.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/ckpt_{}.pth'.format(model_name))

    return test_loss / total, acc

# %% [markdown]
# ## 3. Train Model

# %%
from IPython.display import clear_output
import numpy as np

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),
                      lr=0.001, momentum=0.9, weight_decay=5e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, 2, gamma=0.5) # понижение learning rate на 0.5 на каждой второй эпохе

# %%
train_losses = []
test_losses = []
best_acc = 0
best_epoch = -1
for i in range(10):
    train_loss, train_acc = train(model, optimizer, criterion, trainloader, i, device)
    train_losses.append(train_loss)
    test_loss, test_acc = test(model, criterion, testloader, i, device, best_acc)
    scheduler.step(test_loss) # scheduler expects a tensor or float, so test_loss can remain a tensor here if scheduler can handle it, or convert to .item()
    test_losses.append(test_loss.item()) # Convert tensor to Python number
    best_acc = max(best_acc, test_acc)
    best_epoch = i if best_acc == test_acc else best_epoch
    clear_output()
    plt.figure(figsize=(18, 9))
    plt.plot(np.arange(len(train_losses)), train_losses, label=f'Train, loss: {train_loss:.4f}, Acc: {train_acc}')
    plt.plot(np.arange(len(test_losses)), test_losses, label=f'Test, loss: {test_loss:.4f}, Acc: {test_acc}')
    plt.title(f'Epoch {i}')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# Accuracy в %:

# %%
best_acc
# Out:
# 58.05

# %%
plt.figure(figsize=(18, 9))
plt.plot(np.arange(len(train_losses)), train_losses, label=f'Train, loss: {train_loss:.4f}, Acc: {train_acc}')
plt.plot(np.arange(len(test_losses)), test_losses, label=f'Test, loss: {test_loss:.4f}, Acc: {test_acc}')
plt.plot(np.ones(10)*best_epoch, np.linspace(np.min(train_losses).item(), np.max(test_losses).item(), 10), color='r', label='best epoch')
plt.title(f'Epoch {i}')
plt.legend(loc='best')

# %% [markdown]
# ### BatchNorm
#
# https://arxiv.org/abs/1502.03167
#
# ![](https://standardfrancis.files.wordpress.com/2015/04/screenshot-from-2015-04-16-133436.png)

# %%
model = nn.Sequential()

# dense "head"
model.add_module('conv1', nn.Conv2d(3, 64, 3))
model.add_module('conv1_relu', nn.ReLU())
model.add_module('bn1', nn.BatchNorm2d(64)) # добавили батчнорм
model.add_module('conv2', nn.Conv2d(64, 10, 3))
model.add_module('bn2', nn.BatchNorm2d(10)) # добавили батчнорм
model.add_module('conv2_relu', nn.ReLU())

model.add_module('flat', Flatten())
model.add_module('dense', nn.Linear(10*28*28, 10))

# %%
torchsummary.summary(model.cuda(), (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 30, 30]           1,792
#               ReLU-2           [-1, 64, 30, 30]               0
#        BatchNorm2d-3           [-1, 64, 30, 30]             128
#             Conv2d-4           [-1, 10, 28, 28]           5,770
#        BatchNorm2d-5           [-1, 10, 28, 28]              20
#               ReLU-6           [-1, 10, 28, 28]               0
#            Flatten-7                 [-1, 7840]               0
#             Linear-8                   [-1, 10]          78,410
# ================================================================
# Total params: 86,120
# Trainable params: 86,120
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.56
# Params size (MB): 0.33
# Estimated Total Size (MB): 1.90
# ----------------------------------------------------------------

# %% [markdown]
# Количество параметров увеличилось из-за обучаемых параметров гамма и бета. На пред. слое было 64 параметра, но из-за гамма и бета получается 64*2=128

# %%
model = model.to(device)


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),
                      lr=0.001, momentum=0.9, weight_decay=5e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, 2, gamma=0.5)

# %%
train_losses = []
test_losses = []
best_acc = 0
best_epoch = -1
for i in range(10):
    train_loss, train_acc = train(model, optimizer, criterion, trainloader, i, device)
    train_losses.append(train_loss)
    test_loss, test_acc = test(model, criterion, testloader, i, device, best_acc, 'with_bn')
    scheduler.step(test_loss)
    test_losses.append(test_loss.item())
    best_acc = max(best_acc, test_acc)
    best_epoch = i if best_acc == test_acc else best_epoch
    clear_output()
    plt.figure(figsize=(18, 9))
    plt.plot(np.arange(len(train_losses)), train_losses, label=f'Train, loss: {train_loss:.4f}, Acc: {train_acc}')
    plt.plot(np.arange(len(test_losses)), test_losses, label=f'Test, loss: {test_loss:.4f}, Acc: {test_acc}')
    plt.title(f'Epoch {i}')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# Accuracy в %:

# %%
best_acc
# Out:
# 63.19

# %%
plt.figure(figsize=(18, 9))
plt.plot(np.arange(len(train_losses)), train_losses, label=f'Train, loss: {train_loss:.4f}, Acc: {train_acc}')
plt.plot(np.arange(len(test_losses)), test_losses, label=f'Test, loss: {test_loss:.4f}, Acc: {test_acc}')
plt.plot(np.ones(10)*best_epoch, np.linspace(np.min(train_losses).item(), np.max(test_losses).item(), 10), color='r', label='best epoch')
plt.title(f'Epoch {i}')
plt.legend(loc='best')

# %% [markdown]
# При запуске ноутбука на семинаре было так, что качество улучшилось, но модель переобучалась быстрее – лучшая эпоха теперь 7, а не 8
#
# Один из вариантов – собрать больше данных, но это как правило сложно. Поэтому попробуем аугментацию
#
# Но здесь у нас наоборот, в первом случае лучшая эпоха была 8, а здесь последняя, 10. Тестовый лосс не возрастает

# %% [markdown]
# ## 4. Add some augmentations

# %% [markdown]
# https://pytorch.org/docs/stable/torchvision/transforms.html

# %% [markdown]
# Добавим пару аугментаций (`Crop` & `Flip`) и посмотрим, как изменится обучение

# %%
transform_train = transforms.Compose([
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), # увеличение яркости, констрастности и насыщенности
    transforms.RandomRotation(25),  # случайный поворот по центральной оси
    transforms.RandomHorizontalFlip(), # поворот на 180 градусов (отражение)
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

# но для тестового датасета мы не применяем это
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# %%
model = nn.Sequential()

# dense "head"
model.add_module('conv1', nn.Conv2d(3, 64, 3))
model.add_module('bn1', nn.BatchNorm2d(64))
model.add_module('conv1_relu', nn.ReLU())
model.add_module('conv2', nn.Conv2d(64, 10, 3))
model.add_module('bn2', nn.BatchNorm2d(10))
model.add_module('conv2_relu', nn.ReLU())

model.add_module('flat', Flatten())
model.add_module('dense', nn.Linear(10*28*28, 10))

# %%
def train(model, optim, criterion, dataloader, epoch, device, add_noise=True):
    total = 0
    correct = 0
    train_loss = 0

    model.train()
    for data, label in dataloader:
        if add_noise:
            data = data + torch.empty(*data.size()).normal_(0, 0.0001)
        data, label = data.to(device), label.to(device)
        optim.zero_grad()
        output = model(data)
        loss = criterion(output, label)
        loss.backward()
        optim.step()

        train_loss += loss.item()
        pred = output.argmax(1)
        total += output.shape[0]
        correct += pred.eq(label).sum().item()
    return train_loss / total, 100. * correct / total

# %%
model = model.to(device)


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),
                      lr=0.001, momentum=0.9, weight_decay=5e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, 2, gamma=0.5)

# %%
train_losses = []
test_losses = []
best_acc = 0
best_epoch = -1
for i in range(10):
    train_loss, train_acc = train(model, optimizer, criterion, trainloader, i, device)
    train_losses.append(train_loss)
    test_loss, test_acc = test(model, criterion, testloader, i, device, best_acc, 'bn_and_aug')
    scheduler.step(test_loss)
    test_losses.append(test_loss.item())
    best_acc = max(best_acc, test_acc)
    best_epoch = i if best_acc == test_acc else best_epoch
    clear_output()
    plt.figure(figsize=(18, 9))
    plt.plot(np.arange(len(train_losses)), train_losses, label=f'Train, loss: {train_loss:.4f}, Acc: {train_acc}')
    plt.plot(np.arange(len(test_losses)), test_losses, label=f'Test, loss: {test_loss:.4f}, Acc: {test_acc}')
    plt.title(f'Epoch {i}')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# По итогу стало лучше – изображений стало больше и за такое количество эпох модель не переобучается, лосс только убывает, хотя accuracy немного пострадал

# %%
best_acc
# Out:
# 62.42
